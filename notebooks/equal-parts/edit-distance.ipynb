# %% [markdown]
# Load 4 part cocktails from cocktaildb backup, build a graph by edit distance.

# %%
import pandas as pd
import numpy as np
import networkx as nx

# %%
recipes = pd.read_csv("4_equal_parts-2025-08-02_91819.csv")

# %%
recipe_ingredients = recipes.groupby('recipe_name')['ingredient_id'].apply(set).to_dict()
ingredients = recipes[['ingredient_id', 'ingredient_name']].drop_duplicates()

recipe_names = list(recipe_ingredients.keys())
n = len(recipe_names)
distance_matrix = np.zeros((n, n), dtype=int)

for i, id1 in enumerate(recipe_names):
    for j, id2 in enumerate(recipe_names):
        if i <= j:
            diff = recipe_ingredients[id1] ^ recipe_ingredients[id2]
            distance = len(diff)
            distance_matrix[i, j] = distance
            distance_matrix[j, i] = distance  # symmetric

# Create a DataFrame for easier viewing
distance_df = pd.DataFrame(distance_matrix, index=recipe_names, columns=recipe_names)

# Count number of distance 2 connections for each recipe
distance_2_counts = (distance_df == 2).sum(axis=1)

# Order recipe_names by number of distance 2 connections, descending
recipe_names_by_distance2 = distance_2_counts.sort_values(ascending=False).index.tolist()

# Reorder distance_matrix so the order matches recipe_names_by_distance2
distance_df = distance_df.loc[recipe_names_by_distance2, recipe_names_by_distance2]
distance_matrix = distance_df.values

# %%
distance_df
# Out:
#                      Last Word  Wordsmith  Fir Geddaboudit  Dirty Word  \
# Last Word                    0          2                2           2
# Wordsmith                    2          0                2           2
# Fir Geddaboudit              2          2                0           2
# Dirty Word                   2          2                2           0
# Bitter Last Words            2          2                2           2
# ...                        ...        ...              ...         ...
# Ragnarök                     8          8                8           8
# Shrunken Skull               6          6                6           6
# Sideways In Reverse          6          6                6           6
# Third Ward                   6          6                6           6
# Walking Dead                 6          6                6           6
#
#                      Bitter Last Words  La Ultima Palabra  Pete's Word  \
# Last Word                            2                  2            2
# Wordsmith                            2                  2            2
# Fir Geddaboudit                      2                  2            2
# Dirty Word                           2                  2            2
# Bitter Last Words                    0                  2            2
# ...                                ...                ...          ...
# Ragnarök                             8                  8            8
# Shrunken Skull                       6                  6            6
# Sideways In Reverse                  6                  6            6
# Third Ward                           6                  6            6
# Walking Dead                         6                  6            6
#
#                      Ultimatum  Latest Word  Final Ward  ...  \
# Last Word                    2            2           4  ...
# Wordsmith                    2            2           4  ...
# Fir Geddaboudit              2            2           4  ...
# Dirty Word                   2            2           4  ...
# Bitter Last Words            2            2           4  ...
# ...                        ...          ...         ...  ...
# Ragnarök                     8            8           6  ...
# Shrunken Skull               6            6           8  ...
# Sideways In Reverse          6            6           8  ...
# Third Ward                   6            6           6  ...
# Walking Dead                 6            6           8  ...
#
#                      Penultimate Word  Lush Life  Shaddock  Safe Word  \
# Last Word                           8          8         8          4
# Wordsmith                           8          8         8          4
# Fir Geddaboudit                     8          8         8          4
# Dirty Word                          8          8         8          4
# Bitter Last Words                   8          8         8          4
# ...                               ...        ...       ...        ...
# Ragnarök                            6          6         4          8
# Shrunken Skull                      8          8         8          6
# Sideways In Reverse                 8          8         6          6
# Third Ward                          8          8         8          4
# Walking Dead                        8          6         8          6
#
#                      Quemada's Idol  Ragnarök  Shrunken Skull  \
# Last Word                         6         8               6
# Wordsmith                         4         8               6
# Fir Geddaboudit                   6         8               6
# Dirty Word                        6         8               6
# Bitter Last Words                 6         8               6
# ...                             ...       ...             ...
# Ragnarök                          8         0               8
# Shrunken Skull                    6         8               0
# Sideways In Reverse               6         8               6
# Third Ward                        8         8               8
# Walking Dead                      6         8               6
#
#                      Sideways In Reverse  Third Ward  Walking Dead
# Last Word                              6           6             6
# Wordsmith                              6           6             6
# Fir Geddaboudit                        6           6             6
# Dirty Word                             6           6             6
# Bitter Last Words                      6           6             6
# ...                                  ...         ...           ...
# Ragnarök                               8           8             8
# Shrunken Skull                         6           8             6
# Sideways In Reverse                    0           8             6
# Third Ward                             8           0             8
# Walking Dead                           6           8             0
#
# [77 rows x 77 columns]

# %%
# Create a graph
G = nx.Graph()

# Add all recipe names as nodes
G.add_nodes_from(recipe_names_by_distance2)

# Prepare a list to collect table rows
distance2_table = []

# Add edges between recipes with distance = 2 and collect table data
for i, name1 in enumerate(recipe_names_by_distance2):
    for j, name2 in enumerate(recipe_names_by_distance2):
        if i < j:  # Only check upper triangle to avoid duplicates
            if distance_df.loc[name1, name2] == 2:
                print(f"Adding edge between {name1} and {name2}")
                ingredient_ids = recipe_ingredients[name1] ^ recipe_ingredients[name2]
                ingredient_names = ingredients[ingredients['ingredient_id'].isin(ingredient_ids)]['ingredient_name'].tolist()
                if len(ingredient_names) == 2:
                    G.add_edge(name1, name2, label=f"{ingredient_names[0]} <-> {ingredient_names[1]}")
                    distance2_table.append({
                        "recipe_name_1": name1,
                        "recipe_name_2": name2,
                        "ingredient_name_1": ingredient_names[0],
                        "ingredient_name_2": ingredient_names[1]
                    })
                else:
                    # If not exactly 2, skip or handle as needed
                    print(f"Skipping recipe pair {recipe_names[i]} and {recipe_names[j]} because they have {len(ingredient_names)} ingredients")

print(f"Graph created with {G.number_of_nodes()} nodes and {G.number_of_edges()} edges")
print(f"Recipes with distance 2 connections: {G.number_of_edges()}")

# Write to GML file
nx.write_gml(G, "recipe_distance_2_graph.gml")
print("Graph saved to recipe_distance_2_graph.gml")

# Write out the table as a CSV
distance2_df = pd.DataFrame(distance2_table)
distance2_df.to_csv("distance2_recipe_pairs.csv", index=False)
print("Table of recipe pairs with distance 2 saved to distance2_recipe_pairs.csv")
# Out:
# Adding edge between Last Word and Wordsmith
# Adding edge between Last Word and Fir Geddaboudit
# Adding edge between Last Word and Dirty Word
# Adding edge between Last Word and Bitter Last Words
# Adding edge between Last Word and La Ultima Palabra
# Adding edge between Last Word and Pete's Word
# Adding edge between Last Word and Ultimatum
# Adding edge between Last Word and Latest Word
# Adding edge between Last Word and The Last Monk
# Adding edge between Last Word and Last Ditch
# Adding edge between Last Word and Bad Word
# Adding edge between Wordsmith and Fir Geddaboudit
# Adding edge between Wordsmith and Dirty Word
# Adding edge between Wordsmith and Bitter Last Words
# Adding edge between Wordsmith and La Ultima Palabra
# Adding edge between Wordsmith and Pete's Word
# Adding edge between Wordsmith and Ultimatum
# Adding edge between Wordsmith and Latest Word
# Adding edge between Wordsmith and Final Voyage
# Adding edge between Fir Geddaboudit and Dirty Word
# Adding edge between Fir Geddaboudit and Bitter Last Words
# Adding edge between Fir Geddaboudit and La Ultima Palabra
# Adding edge between Fir Geddaboudit and Pete's Word
# Adding edge between Fir Geddaboudit and Ultimatum
# Adding edge between Fir Geddaboudit and Latest Word
# Adding edge between Dirty Word and Bitter Last Words
# Adding edge between Dirty Word and La Ultima Palabra
# Adding edge between Dirty Word and Pete's Word
# Adding edge between Dirty Word and Ultimatum
# Adding edge between Dirty Word and Latest Word
# Adding edge between Bitter Last Words and La Ultima Palabra
# Adding edge between Bitter Last Words and Pete's Word
# Adding edge between Bitter Last Words and Ultimatum
# Adding edge between Bitter Last Words and Latest Word
# Adding edge between La Ultima Palabra and Pete's Word
# Adding edge between La Ultima Palabra and Ultimatum
# Adding edge between La Ultima Palabra and Latest Word
# Adding edge between Pete's Word and Ultimatum
# Adding edge between Pete's Word and Latest Word
# Adding edge between Ultimatum and Latest Word
# Adding edge between Final Ward and Refined Speech
# Adding edge between Final Ward and Accidental Hipster
# Adding edge between Final Ward and TBD
# Adding edge between Final Ward and Julien Sorel
# Adding edge between Final Ward and The Asterisk
# Adding edge between Refined Speech and Monte Cassino
# Adding edge between Refined Speech and Accidental Hipster
# Adding edge between Refined Speech and Dressed To Kill
# Adding edge between Monte Cassino and Dressed To Kill
# Adding edge between Monte Cassino and Shanghai Gin
# Adding edge between Monte Cassino and Widow's Word
# Adding edge between Paper Plane and Flying Naked
# Adding edge between Paper Plane and Half-Hour Flight
# Adding edge between Paper Plane and Paper Airplane
# Adding edge between Paper Plane and Esprit D'escalier
# Adding edge between Flying Naked and Half-Hour Flight
# Adding edge between Flying Naked and Bourbamaro
# Adding edge between Corpse Reviver No. 2 and Sherry Lady
# Adding edge between Corpse Reviver No. 2 and Sunflower
# Adding edge between Corpse Reviver No. 2 and Hoop La!
# Adding edge between Accidental Hipster and Hipsters Last Word
# Adding edge between Shanghai Gin and Widow's Word
# Adding edge between Sherry Lady and Sunflower
# Adding edge between TBD and Buck & Rider
# Adding edge between Hoop La! and Between The Sheets
# Adding edge between Julien Sorel and Ceil D'or
# Adding edge between The Last Monk and Last Ditch
# Adding edge between The Asterisk and Ceil D'or
# Adding edge between Frozen In A Starry Void and Hipsters Last Word
# Adding edge between Frozen In A Starry Void and Definitive Source
# Adding edge between Swan Song and Adam's Words
# Adding edge between That's My Word and Right Word
# Adding edge between Monologue and Prologue
# Adding edge between Naked And Famous and Spicy Dead Lady
# Graph created with 77 nodes and 74 edges
# Recipes with distance 2 connections: 74
# Graph saved to recipe_distance_2_graph.gml
# Table of recipe pairs with distance 2 saved to distance2_recipe_pairs.csv

# %%
pd.set_option('display.max_rows', None)
distance_df.loc["Last Word"][distance_df.loc["Last Word"] == 4].sort_values(ascending=True)
# Out:
# Final Ward                 4
# Julien Sorel               4
# The Asterisk               4
# Frozen In A Starry Void    4
# Hipsters Last Word         4
# Swan Song                  4
# That's My Word             4
# Right Word                 4
# Adam's Words               4
# Definitive Source          4
# Final Voyage               4
# Benedict's Word            4
# Corpse Defiler #2          4
# Industry Sour              4
# Safe Word                  4
# Name: Last Word, dtype: int64

# %%
[ingredients.query("ingredient_id == @i")["ingredient_name"].values[0] for i in recipe_ingredients["Last Word"]]
# Out:
# ['Maraschino Liqueur', 'Green Chartreuse', 'Gin', 'Lime Juice']

# %%
[
    (recipe_name, [ingredients.query("ingredient_id == @i")["ingredient_name"].values[0] for i in recipe_ingredients[recipe_name]])
    for recipe_name in distance_df.loc["Last Word"][distance_df.loc["Last Word"] == 4].sort_values(ascending=True).index
]
# Out:
# [('Final Ward',
#   ['Lemon Juice', 'Green Chartreuse', 'Rye', 'Maraschino Liqueur']),
#  ('Julien Sorel',
#   ['Lemon Juice', 'Green Chartreuse', 'Cognac', 'Maraschino Liqueur']),
#  ('The Asterisk',
#   ['Lemon Juice', 'Green Chartreuse', 'Cognac', 'Maraschino Liqueur']),
#  ('Frozen In A Starry Void',
#   ['Allspice Dram', 'Maraschino Liqueur', 'Rye', 'Lime Juice']),
#  ('Hipsters Last Word',
#   ['Fernet-Branca', 'Maraschino Liqueur', 'Rye', 'Lime Juice']),
#  ('Swan Song',
#   ['Green Chartreuse', 'Smith and Cross', 'Dry Curaçao', 'Lime Juice']),
#  ("That's My Word", ['Yellow Chartreuse', 'St. Germain', 'Gin', 'Lime Juice']),
#  ('Right Word', ['St. Germain', 'Gin', 'Lillet Blanc', 'Lime Juice']),
#  ("Adam's Words",
#   ['Green Chartreuse', 'Ginger Liqueur', 'Smith and Cross', 'Lime Juice']),
#  ('Definitive Source',
#   ['Allspice Dram', 'Maraschino Liqueur', 'Smith and Cross', 'Lime Juice']),
#  ('Final Voyage',
#   ['Green Chartreuse', 'Apricot Liqueur', 'Black Rum', 'Lime Juice']),
#  ("Benedict's Word",
#   ['Maraschino Liqueur', 'Benedictine', 'Bourbon', 'Lime Juice']),
#  ('Corpse Defiler #2',
#   ['Amaro Nonino Quintessentia', 'Gin', 'Cocchi Americano', 'Lime Juice']),
#  ('Industry Sour',
#   ['Fernet-Branca', 'Green Chartreuse', 'Simple Syrup', 'Lime Juice']),
#  ('Safe Word',
#   ['Maraschino Liqueur', 'Damiana Liqueur', 'Tequila', 'Lime Juice'])]

# %%
[ingredients.query("ingredient_id == @i")["ingredient_name"].values[0] for i in recipe_ingredients["Julien Sorel"]]
# Out:
# ['Lemon Juice', 'Green Chartreuse', 'Cognac', 'Maraschino Liqueur']

# %%
ingredients
# Out:
#      ingredient_id              ingredient_name
# 0               26  Appleton Estate 12 Year Old
# 1               39                  Dry Curaçao
# 2               34   Amaro Nonino Quintessentia
# 3               32                  Lemon Juice
# 4               22                          Rye
# 5               41                  Benedictine
# 6               40            Yellow Chartreuse
# 8                4                          Gin
# 12              10                      Bourbon
# 14              42                       Aperol
# 18              64                Fernet-Branca
# 19              16           Maraschino Liqueur
# 20              19              Smith and Cross
# 21              15                   Lime Juice
# 22              65             Green Chartreuse
# 23              50               Ginger Liqueur
# 24              66             Reposado Tequila
# 26              73                        Cynar
# 27              88        Rabarbaro Zucca Amaro
# 28              67                      Aquavit
# 31              89                  Amaro Abano
# 35              91                Gran Classico
# 38              92                Amaro Sibilla
# 39              93                  Honey Syrup
# 42              90             Amaro Montenegro
# 43              94                   Barenjager
# 48              68                       Cognac
# 50              95                    Cointreau
# 51               2                          Rum
# 54              53                      Campari
# 55              69              Apricot Liqueur
# 56              12            Angostura Bitters
# 60              28               Blended Scotch
# 61              96                 Orange Juice
# 62              55               Sweet Vermouth
# 63              36               Cherry Heering
# 71              97         Bigallet China China
# 75              98               Mathilde Poire
# 79              70             Cocchi Americano
# 80               6                      Tequila
# 83              99          Pineapple Gum Syrup
# 87              84                 Lillet Blanc
# 91             100        Crème De Pamplemousse
# 92              72                Añejo Tequila
# 101             45             Grapefruit Juice
# 104             74               Batavia Arrack
# 106             33              Velvet Falernum
# 107            101                       Strega
# 108            102                Pineapple Rum
# 112             75                        Pisco
# 115            103                Rhubarb Syrup
# 116             46                    Black Rum
# 126            104       Douglas Fir Eau De Vie
# 134              8                Allspice Dram
# 139             76    Ancho Reyes Chili Liqueur
# 140             77            Bison Grass Vodka
# 142             81                 Dolin Génépy
# 155             14                 Simple Syrup
# 160             78                       Mezcal
# 166             79                Ricard Pastis
# 172             80                      Genever
# 186             82                Jaegermeister
# 187            107                      Solerno
# 202             83                Peach Liqueur
# 203            108                       Averna
# 204             29                 Peaty Scotch
# 212            106                     Aged Rum
# 215            105             Donn's Spices #2
# 227             57                  St. Germain
# 230            109              Damiana Liqueur
# 239            111                   Dry Sherry
# 240             47                 Demerara Rum
# 243            110                    Grenadine
# 244             85                 Apple Brandy
# 274             86         Aromas De Montserrat
# 280             49              Appleton Estate
# 284             87                 Zwack Unicum
# 300              3                        Vodka
# 304            176                      Cachaça
# 305            171               Blanc Vermouth
# 306            145     Giffard Banane Du Bresil
